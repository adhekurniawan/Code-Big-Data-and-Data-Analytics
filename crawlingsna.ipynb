# %%
install.packages("httr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("twitteR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘rjson’

# %%
library("httr")

# %%
library("twitteR")

# %%
#setup_twitter_oauth("ConsumerKey","ConsumerSecretKey", "AccessToken", "AccessSecretToken")
setup_twitter_oauth('SKhNoNqUOVeIWd7idAvJPc90C','jvRpYcQgsAB7UbcNaXvfGyOxHto9h3BFMYaHPVgPqqVDmL1A4G','1452233843411456009-0X3svk3kP20xz9VmG79DAWRQORArNe','HhBjOHXt5clQjXIwSyluJbiiygYxTv78zdUaFvdXHm8LF')
# Out:
# [1] "Using direct authentication"
# Error in check_twitter_oauth(): OAuth authentication error:
# This most likely means that you have incorrectly called setup_twitter_oauth()'
# Traceback:
#
# 1. setup_twitter_oauth("SKhNoNqUOVeIWd7idAvJPc90C", "jvRpYcQgsAB7UbcNaXvfGyOxHto9h3BFMYaHPVgPqqVDmL1A4G",
#  .     "1452233843411456009-0X3svk3kP20xz9VmG79DAWRQORArNe", "HhBjOHXt5clQjXIwSyluJbiiygYxTv78zdUaFvdXHm8LF")
# 2. check_twitter_oauth()
# 3. stop("OAuth authentication error:\nThis most likely means that you have incorrectly called setup_twitter_oauth()'")

# %%
tweets<- searchTwitter("#covid",lang="en", n=1000)

# %%
tweets<- twListToDF(tweets)

# %%
write.csv(tweets,"covid.csv", row.names = FALSE)
